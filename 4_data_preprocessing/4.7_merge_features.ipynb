# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.append(str(PROJECT_ROOT))

import os
from functools import reduce

import pandas as pd

from utils.paths import EXTRACTED_FEATURES_DIR

# %%
# Load CSVs
df_basic = pd.read_csv(EXTRACTED_FEATURES_DIR / "simple_feature_extraction.csv")
df_aoi = pd.read_csv(EXTRACTED_FEATURES_DIR / "fixation_distance_aoi.csv")
df_latency = pd.read_csv(EXTRACTED_FEATURES_DIR / "latency.csv")
df_fic_ffd = pd.read_csv(EXTRACTED_FEATURES_DIR / "fic_ffd_features.csv")

# Extract sets of HASHes
hashes_basic = set(df_basic["HASH"])
hashes_aoi = set(df_aoi["HASH"])
hashes_latency = set(df_latency["HASH"])
hashes_fic_ffd = set(df_fic_ffd["HASH"])

# Get the union of all hashes
all_hashes = hashes_basic | hashes_aoi | hashes_latency | hashes_fic_ffd

# Create a quick summary table
summary = []
for h in all_hashes:
    summary.append(
        {
            "HASH": h,
            "in_basic": h in hashes_basic,
            "in_aoi": h in hashes_aoi,
            "in_latency": h in hashes_latency,
            "in_fic_ffd": h in hashes_fic_ffd,
        }
    )

df_summary = pd.DataFrame(summary)

# Filter for any HASH not present in all 4 files
missing_hashes = df_summary[
    ~(df_summary[["in_basic", "in_aoi", "in_latency", "in_fic_ffd"]].all(axis=1))
]
missing_hashes
# Out:
#                    HASH  in_basic  in_aoi  in_latency  in_fic_ffd
# 22  2024-03-27_11-19-10     False    True        True        True

# %% [markdown]
# Remove row from AOI, latency, and FIC_FDD files.

# %%
# Merge on 'HASH' using INNER JOIN to keep only participants present in all files
dfs = [df_basic, df_aoi, df_latency, df_fic_ffd]
merged_df = reduce(lambda left, right: pd.merge(left, right, on='HASH', how='inner'), dfs)

# Check for missing values
missing = merged_df.isnull().sum()
missing_nonzero = missing[missing > 0]
print("Columns with missing values:\n", missing_nonzero)
# Out:
# Columns with missing values:
#  Series([], dtype: int64)

# %%
merged_df.columns
# Out:
# Index(['participant_folder', 'HASH', 'group', 'mean_fix_duration',
#        'median_fix_duration', 'mean_saccade_length', 'median_saccade_length',
#        'mean_blink_duration', 'median_blink_duration', 'num_fixations_per_min',
#        'num_blinks_per_min', 'num_saccades_per_min', 'age', 'ran_score',
#        'filename_x', 'folder_x', 'mean_fix_dist_to_object',
#        'median_fix_dist_to_object', 'mean_fix_dist_to_fruit',
#        'median_fix_dist_to_fruit', 'percent_fixations_outside_bbox',
#        'mean_latency', 'median_latency', 'std_latency', 'min_latency',
#        'max_latency', 'percent_unseen_fruits', 'n_fruits', 'n_seen',
#        'folder_y', 'participant', 'filename_y', 'folder', 'FIC_mean',
#        'FIC_std', 'FFD'],
#       dtype='object')

# %%
merged_df.drop(columns=['folder_x', 'folder_y', 'participant'], inplace=True)

# %%
rows_with_missing = merged_df[merged_df.isnull().any(axis=1)]
rows_with_missing
# Out:
# Empty DataFrame
# Columns: [participant_folder, HASH, group, mean_fix_duration, median_fix_duration, mean_saccade_length, median_saccade_length, mean_blink_duration, median_blink_duration, num_fixations_per_min, num_blinks_per_min, num_saccades_per_min, age, ran_score, filename_x, mean_fix_dist_to_object, median_fix_dist_to_object, mean_fix_dist_to_fruit, median_fix_dist_to_fruit, percent_fixations_outside_bbox, mean_latency, median_latency, std_latency, min_latency, max_latency, percent_unseen_fruits, n_fruits, n_seen, filename_y, folder, FIC_mean, FIC_std, FFD]
# Index: []
#
# [0 rows x 33 columns]

# %%
# Quick Describe Check
check = merged_df.describe()
pd.set_option('display.max_columns', 100) 
check
# Out:
#        mean_fix_duration  median_fix_duration  mean_saccade_length  \
# count          58.000000            58.000000            58.000000
# mean          360.054330           275.646552           129.958983
# std            60.212738            43.557686            22.104997
# min           244.295493           185.000000            91.451013
# 25%           323.796098           245.000000           116.075241
# 50%           355.620412           272.500000           125.001999
# 75%           411.463392           300.625000           142.250678
# max           473.676140           380.000000           189.616256
#
#        median_saccade_length  mean_blink_duration  median_blink_duration  \
# count              58.000000            58.000000              58.000000
# mean              108.725327           256.527581             255.948276
# std                20.482479            28.973122              29.793984
# min                73.105310           190.000000             190.000000
# 25%                95.563293           242.347413             240.000000
# 50%               104.722898           259.778541             255.000000
# 75%               117.010680           276.425106             278.750000
# max               170.784850           318.870968             320.000000
#
#        num_fixations_per_min  num_blinks_per_min  num_saccades_per_min  \
# count              58.000000           58.000000             58.000000
# mean              145.353352           34.828327            146.887954
# std                20.928403           56.038512             21.522554
# min               112.916298            5.434204            113.392684
# 25%               128.412133           10.292177            129.382937
# 50%               146.491838           17.738211            147.756918
# 75%               157.651808           28.490368            160.081413
# max               199.442590          321.134351            200.429469
#
#              age  ran_score  mean_fix_dist_to_object  \
# count  58.000000  58.000000                58.000000
# mean   18.603448   1.394125               117.912649
# std     8.689457   0.629426                44.509157
# min     4.000000   0.317460                72.430104
# 25%     6.000000   0.755556                93.900061
# 50%    24.000000   1.584141               108.123224
# 75%    24.000000   1.875000               125.370819
# max    34.000000   2.473411               354.002472
#
#        median_fix_dist_to_object  mean_fix_dist_to_fruit  \
# count                  58.000000               58.000000
# mean                   76.608261              120.213763
# std                    35.396286               47.817142
# min                    47.172079               73.958190
# 25%                    62.099600               95.955490
# 50%                    71.060068              110.665581
# 75%                    81.295448              127.956204
# max                   315.613025              379.400605
#
#        median_fix_dist_to_fruit  percent_fixations_outside_bbox  mean_latency  \
# count                 58.000000                       58.000000     58.000000
# mean                  78.969528                       37.488906    140.721966
# std                   46.069260                        7.195255     82.106211
# min                   46.548320                       26.439791      0.000000
# 25%                   62.256813                       32.452875     96.651519
# 50%                   72.010733                       35.127494    121.205950
# 75%                   83.257355                       40.814489    157.924869
# max                  402.502371                       58.427474    518.958305
#
#        median_latency  std_latency  min_latency   max_latency  \
# count       58.000000    58.000000         58.0     58.000000
# mean        15.795360   453.708596          0.0   3971.324412
# std         21.633849   491.709668          0.0   5506.430283
# 42  2024-06-06_08-28-26
# 43  2024-06-05_10-56-25
# 44  2025-05-08_09-09-51
# 45  2024-06-05_10-01-57
# 46  2025-04-28_08-36-20
# 47  2024-03-08_13-36-24
# 48  2024-03-08_15-41-30
# 49  2025-04-22_09-53-23
# 50  2024-06-11_13-47-59
# 51  2024-03-21_14-03-47
# 52  2024-03-08_14-14-27
# 53  2024-03-25_13-21-43
# 54  2025-04-16_11-29-18
# 55  2024-03-08_16-18-12
# 56  2024-03-21_14-29-21
# 57  2025-04-25_15-41-32

# %%
# Drop participant with faulty latency files
merged_df.drop(index=1, axis=0, inplace=True)

# Drop Minimum Latency due to no variance
merged_df.drop(columns=['min_latency'], inplace=True)

print('Number of participants: ', len(merged_df))
print('Number of features:', len(merged_df.columns))
merged_df.head()
# Out:
# Number of participants:  57
# Number of features: 32
#                                   participant_folder                 HASH  \
# 0  Filtered_DysCover_2024-06-05_10-34-55-e4242330...  2024-06-05_10-34-55
# 2  Filtered_DysCover_2024-06-06_13-47-36-8fd41dd9...  2024-06-06_13-47-36
# 3  Filtered_Adult_Spring_2025-04-17_11-52-56-866f...  2025-04-17_11-52-56
# 4  Filtered_DysCover_2024-06-06_10-02-38-8cf987ec...  2024-06-06_10-02-38
# 5  Filtered_Adult_Spring_2025-03-31_09-49-48-2738...  2025-03-31_09-49-48
#
#          group  mean_fix_duration  median_fix_duration  mean_saccade_length  \
# 0     dyscover         355.413534                262.5           174.593112
# 2     dyscover         470.317419                335.0           156.351444
# 3  adultspring         294.963428                230.0           141.825833
# 4     dyscover         343.966074                250.0           133.209223
# 5  adultspring         283.525456                225.0           135.272819
#
#    median_saccade_length  mean_blink_duration  median_blink_duration  \
# 0             129.459258           205.357143                  205.0
# 2             136.706395           221.576577                  220.0
# 3             120.966473           261.256614                  260.0
# 4             107.781549           226.363636                  225.0
# 5             112.704527           264.636364                  265.0
#
#    num_fixations_per_min  num_blinks_per_min  num_saccades_per_min   age  \
# 0             146.369736           74.811095            148.383351   5.0
# 2             114.855289           25.175696            116.462045   5.0
# 3             166.670052           23.233069            171.674232  24.0
# 4             149.941643           11.025390            150.722713   6.0
# 5             163.782630           36.223401            163.857260  24.0
#
#    ran_score                                         filename_x  \
# 0   0.465116  annotated_gaze_Filtered_DysCover_2024-06-05_10...
# 2   0.317460  annotated_gaze_Filtered_DysCover_2024-06-06_13...
# 3   1.578283  annotated_gaze_Filtered_Adult_Spring_2025-04-1...
# 4   0.425532  annotated_gaze_Filtered_DysCover_2024-06-06_10...
# 5   0.894454  annotated_gaze_Filtered_Adult_Spring_2025-03-3...
#
#    mean_fix_dist_to_object  median_fix_dist_to_object  mean_fix_dist_to_fruit  \
# 0               208.377782                 120.579690              206.565141
# 2               140.894247                  96.259168              143.181880
# 3               123.376752                  87.011314              124.044827
# 4               108.886629                  74.049489              111.309669
# 5                93.544382                  62.203953               95.677422
#
#    median_fix_dist_to_fruit  percent_fixations_outside_bbox  mean_latency  \
# 0                120.345183                       42.560554      0.000000
# 2                 99.125023                       37.701396    140.196226
# 3                 86.173297                       40.654206    518.958305
# 4                 75.628590                       33.187773    201.257322
# 5                 63.721096                       35.254989    175.293621
#
#    median_latency  std_latency   max_latency  percent_unseen_fruits  n_fruits  \
# 0        0.000000     0.000000      0.000000              97.037037       135
# 2       47.500000   365.766599   2887.624023              88.253968       630
# 3       20.000000  3332.941826  35572.454102              88.453815       996
# 4       35.125000   507.622451   3368.125244              83.836858       662
# 5       10.000244   512.109161   3763.499756              71.122536      1167
#
#    n_seen                                         filename_y  \
# 0       4  annotated_gaze_Filtered_DysCover_2024-06-05_10...
# 2      74  annotated_gaze_Filtered_DysCover_2024-06-06_13...
# 3     115  annotated_gaze_Filtered_Adult_Spring_2025-04-1...
# 4     107  annotated_gaze_Filtered_DysCover_2024-06-06_10...
# 5     337  annotated_gaze_Filtered_Adult_Spring_2025-03-3...
#
#                                               folder   FIC_mean    FIC_std  \
# 0  Filtered_DysCover_2024-06-05_10-34-55-e4242330...  27.698962  39.505981
# 2  Filtered_DysCover_2024-06-06_13-47-36-8fd41dd9...  30.168636  39.585317
# 3  Filtered_Adult_Spring_2025-04-17_11-52-56-866f...  27.716706  40.490290
# 4  Filtered_DysCover_2024-06-06_10-02-38-8cf987ec...  29.181659  37.661028
# 5  Filtered_Adult_Spring_2025-03-31_09-49-48-2738...  19.569845  31.326708
#
#         FFD
# 0  1.235903
# 2  1.270388
# 3  1.218467
# 4  1.236929
# 5  1.181386

# %%
print("length of df:", len(merged_df))
print("columns of df:", merged_df.columns)
print("group counts", merged_df.groupby("group").size())
# Out:
# length of df: 57
# columns of df: Index(['participant_folder', 'HASH', 'group', 'mean_fix_duration',
#        'median_fix_duration', 'mean_saccade_length', 'median_saccade_length',
#        'mean_blink_duration', 'median_blink_duration', 'num_fixations_per_min',
#        'num_blinks_per_min', 'num_saccades_per_min', 'age', 'ran_score',
#        'filename_x', 'mean_fix_dist_to_object', 'median_fix_dist_to_object',
#        'mean_fix_dist_to_fruit', 'median_fix_dist_to_fruit',
#        'percent_fixations_outside_bbox', 'mean_latency', 'median_latency',
#        'std_latency', 'max_latency', 'percent_unseen_fruits', 'n_fruits',
#        'n_seen', 'filename_y', 'folder', 'FIC_mean', 'FIC_std', 'FFD'],
#       dtype='object')
# group counts group
# adultspring    26
# dyscover       17
# fruitninja     14
# dtype: int64

# %%
# -- SAVE AS CSV ---
output_csv_path = EXTRACTED_FEATURES_DIR / 'merged_features.csv'
overwrite = False  # Set to True if you want to overwrite existing files

if not os.path.exists(output_csv_path) or overwrite:
    merged_df.to_csv(output_csv_path, index=False)
    print(f"Features saved to {output_csv_path}")

else:
    print(f"File already exists: {output_csv_path}. Not overwriting.")
# Out:
# File already exists: /HOME/lecomteo/thesis/master_thesis/data/processed/extracted_features/merged_features.csv. Not overwriting.
